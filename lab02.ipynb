# %%
#CSC467 Computer Vision and Pattern Recognition
## Lab 2 Basic Image Processing
### Mehul Rajpal

# %%
# !pip install opencv-python-headless
# !pip install scikit-image

import cv2
import numpy as np
from matplotlib import pyplot as plt
from mpl_toolkits import mplot3d
from skimage import io as io_url
# Out:
# ...
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python3 -m pip install --upgrade pip
# ...
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python3 -m pip install --upgrade pip

# %%
frame = io_url.imread('https://raw.githubusercontent.com/M0hzz/M0hzz-CSC467-Week-2-Lab/main/Lena.png')
frame = np.float32(frame) / 255
plt.imshow(frame)

# %%
print(frame.shape)
# Out:
# (512, 512, 3)

# %%
frm= frame[0:100,0:100,0]

plt.imshow(frm, cmap="gray")

# %%
new_array = frm+20

plt.imshow(new_array, cmap='gray')

# %%
kernel_size = (5, 5)
mean_filtered_frame = cv2.blur(frame, kernel_size)

# %%
axes[1].imshow(mean_filtered_frame)
plt.imshow(mean_filtered_frame)

# %%
sharpening_kernel = np.array([[0, -1, 0],
                              [-1,  5, -1],
                              [0, -1, 0]], dtype=np.float32)

sharpened_frame = cv2.filter2D(frame, -1, sharpening_kernel)

# %%
axes[1].imshow(sharpened_frame)
plt.imshow(sharpened_frame)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.7294118..1.8941176].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.7294118..1.8941176].

# %%
frm1= frame[:,:,0]

plt.imshow(frm1, cmap="gray")

# %%
edges_red_channel = cv2.Canny((frm1 * 255).astype(np.uint8), threshold1=100, threshold2=200)

# %%
axes[1].imshow(edges_red_channel, cmap="gray")
plt.imshow(edges_red_channel)

# %%
frame2 = io_url.imread('https://raw.githubusercontent.com/M0hzz/M0hzz-CSC467-Week-2-Lab/main/baboon.png')
frame2 = np.float32(frame2) / 255
plt.imshow(frame2)

# %%
kernel_size = (5, 5)
mean_filtered_frame2 = cv2.blur(frame2, kernel_size)

# %%
axes[1].imshow(mean_filtered_frame2)
plt.imshow(mean_filtered_frame2)

# %%
sharpening_kernel2 = np.array([[0, -1, 0],
                              [-1,  5, -1],
                              [0, -1, 0]], dtype=np.float32)

sharpened_frame2 = cv2.filter2D(frame2, -1, sharpening_kernel2)

# %%
axes[1].imshow(sharpened_frame2)
plt.imshow(sharpened_frame2)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.5843138..2.7882352].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.5843138..2.7882352].

# %%
frm2= frame2[:,:,0]

plt.imshow(frm2, cmap="gray")

# %%
edges_red_channel2 = cv2.Canny((frm2 * 255).astype(np.uint8), threshold1=100, threshold2=200)

# %%
axes[1].imshow(edges_red_channel2, cmap="gray")
plt.imshow(edges_red_channel2)
